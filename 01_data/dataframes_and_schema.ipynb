# %% [markdown]
# <a href="https://colab.research.google.com/github/natalie-s11/DS2022/blob/main/01_data/dataframes_and_schema.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import polars as pl

url = "https://s3.amazonaws.com/uvasds-systems/data/FLIGHT_LOGS.csv"

# %% [markdown]
# # Pandas

# %%
# pandas
df_pd = pd.read_csv(url)
print(df_pd.head())

len(df_pd)
df_pd.shape
# Out:
#   flight_number       airline_name              departure_airport  \
# 0        AI2923          Air India    Indira Gandhi International
# 1        LH7040          Lufthansa              Frankfurt Airport
# 2        AA4621  American Airlines  John F. Kennedy International
# 3        SK8375   SAS Scandinavian             Copenhagen Airport
# 4        LH3446          Lufthansa              Frankfurt Airport
#
#   departure_city departure_country departure_time  \
# 0          Delhi             India       11:12 AM
# 1      Frankfurt           Germany        2:42 AM
# 2       New York               USA        6:00 PM
# 3     Copenhagen           Denmark        4:26 PM
# 4      Frankfurt           Germany        7:10 AM
#
#                      arrival_airport arrival_city arrival_country  \
# 0  Chhatrapati Shivaji International       Mumbai           India
# 1                  Charles de Gaulle        Paris          France
# ...

# %%
df_pd.dtypes
df_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   flight_number      1000 non-null   object
#  1   airline_name       1000 non-null   object
#  2   departure_airport  1000 non-null   object
#  3   departure_city     1000 non-null   object
#  4   departure_country  1000 non-null   object
#  5   departure_time     1000 non-null   object
#  6   arrival_airport    1000 non-null   object
#  7   arrival_city       1000 non-null   object
#  8   arrival_country    1000 non-null   object
#  9   duration_hours     1000 non-null   int64
#  10  passenger_name     1000 non-null   object
#  11  passenger_age      1000 non-null   int64
#  12  passenger_gender   1000 non-null   object
#  13  seat_number        1000 non-null   object
#  14  ticket_price       1000 non-null   object
#  15  baggage_weight     1000 non-null   int64
# ...

# %% [markdown]
# # Polars

# %%
# polars
df_pl = pl.read_csv(url)
print(df_pl.head())

df_pl.height
df_pl.shape
# Out:
# shape: (5, 20)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ flight_nu ┆ airline_n ┆ departure ┆ departure ┆ … ┆ meal_pref ┆ flight_st ┆ gate_numb ┆ arrival_ │
# │ mber      ┆ ame       ┆ _airport  ┆ _city     ┆   ┆ erence    ┆ atus      ┆ er        ┆ date     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ i64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ AI2923    ┆ Air India ┆ Indira    ┆ Delhi     ┆ … ┆ Vegan     ┆ On time   ┆ 34        ┆ 5/4/2022 │
# │           ┆           ┆ Gandhi    ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Internati ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
# df_pl.schema

print("\nSchema:")
for name, dtype in df_pl.schema.items():
    print(f"  {name}: {dtype}")
# Out:
# Schema:
#   flight_number: String
#   airline_name: String
#   departure_airport: String
#   departure_city: String
#   departure_country: String
#   departure_time: String
#   arrival_airport: String
#   arrival_city: String
#   arrival_country: String
#   duration_hours: Int64
#   passenger_name: String
#   passenger_age: Int64
#   passenger_gender: String
#   seat_number: String
#   ticket_price: String
#   baggage_weight: Int64
#   meal_preference: String
#   flight_status: String
#   gate_number: Int64
#   arrival_date: String
